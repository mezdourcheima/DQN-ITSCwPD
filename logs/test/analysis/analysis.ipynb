# %% [markdown]
# # Analysis of Model Performance

# %% [markdown]
# ## Step 1: Statistical Summary

# %%
import pandas as pd

# Load the CSV file
file_path = '/Users/cheimamezdour/Projects/PFE/DQN-ITSCwPD/logs/test/J7_TLS/con/dataDuelingDoubleDQNAgent_lr0.0001.csv'
data = pd.read_csv(file_path)

# Statistical summary of the dataset
stat_summary = data.describe()
stat_summary
# Out:
#                   l             r            ep    con_p_rate
# count  11139.000000  11139.000000  11139.000000  11139.000000  \
# mean     785.184936  43518.269607    210.053865      0.498630
# std        9.871235   7739.490159    125.990954      0.291465
# min      750.000000 -57221.477243      1.000000      0.000000
# 25%      779.000000  43888.879422    101.000000      0.246000
# 50%      785.000000  44583.654808    206.000000      0.496000
# 75%      792.000000  45270.899475    318.000000      0.749000
# max      822.000000  48626.335939    438.000000      1.000000
#
#        ctrl_con_p_rate         veh_n     sum_delay  sum_waiting_time
# count     11139.000000  11139.000000  11139.000000      11139.000000  \
# mean          0.498630     11.479397     10.810716         39.453093
# std           0.291465      1.434511      1.541358         47.783514
# min           0.000000      5.000000      4.100315          0.000000
# 25%           0.246000     11.000000      9.753694          2.000000
# 50%           0.496000     12.000000     10.764647         22.000000
# 75%           0.749000     12.000000     11.813941         67.000000
# max           1.000000     15.000000     14.702605        866.000000
#
#        sum_acc_waiting_time  sum_queue_length     avg_delay  avg_waiting_time
# count          11139.000000      11139.000000  11139.000000      11139.000000  \
# mean              96.208726          4.372385      0.939895          3.298325
# std               59.137524          3.201939      0.032476          3.943937
# min                0.000000          0.000000      0.818336          0.000000
# 25%               52.000000          1.000000      0.916048          0.181818
# 50%               84.000000          4.000000      0.949534          1.727273
# 75%              126.000000          8.000000      0.965492          5.600000
# max              910.000000         12.000000      1.000000         66.615385
#
#        avg_acc_waiting_time  avg_queue_length  total_density    total_flow
# count          11139.000000      11139.000000   11139.000000  11139.000000  \
# mean               8.256277          0.874477       0.309667     11.049376
# std                4.837873          0.640388       0.039137      1.378296
# min                0.000000          0.000000       0.169393      6.000000
# 25%                4.692308          0.200000       0.279418     10.000000
# 50%                7.181818          0.800000       0.308063     11.000000
# 75%               10.636364          1.600000       0.338785     12.000000
# max               70.000000          2.400000       0.364115     13.000000
#
#        total_ramp_queue_length
# count             11139.000000
# mean                 16.937786
# std                  12.379097
# min                   0.000000
# 25%                   6.000000
# 50%                  15.000000
# 75%                  24.000000
# max                  39.000000

# %% [markdown]
# ## Step 2: Correlation Analysis

# %%
# Correlation matrix for numerical columns
numeric_columns = data.select_dtypes(include='number').columns
correlation_matrix = data[numeric_columns].corr()
correlation_matrix
# Out:
#                                 l         r        ep  con_p_rate
# l                        1.000000  0.088851  0.005832   -0.005977  \
# r                        0.088851  1.000000  0.007215    0.006232
# ep                       0.005832  0.007215  1.000000   -0.010642
# con_p_rate              -0.005977  0.006232 -0.010642    1.000000
# ctrl_con_p_rate         -0.005977  0.006232 -0.010642    1.000000
# veh_n                    0.112051 -0.011389 -0.003409    0.001663
# sum_delay                0.107104 -0.008768 -0.004347    0.000856
# sum_waiting_time         0.042250  0.015446 -0.002770   -0.010716
# sum_acc_waiting_time     0.064513  0.019411  0.000054   -0.012593
# sum_queue_length         0.031627  0.005142 -0.002493   -0.010137
# avg_delay                0.040956  0.005381 -0.006456   -0.000409
# avg_waiting_time         0.033524  0.017684 -0.004336   -0.011835
# avg_acc_waiting_time     0.044167  0.022768 -0.001601   -0.014292
# avg_queue_length         0.031627  0.005142 -0.002493   -0.010137
# total_density            0.002365 -0.002990 -0.000003   -0.007908
# total_flow               0.001797 -0.001692  0.000501   -0.007902
# total_ramp_queue_length  0.010171  0.005812 -0.000255   -0.009358
#
#                          ctrl_con_p_rate     veh_n  sum_delay
# l                              -0.005977  0.112051   0.107104  \
# r                               0.006232 -0.011389  -0.008768
# ep                             -0.010642 -0.003409  -0.004347
# con_p_rate                      1.000000  0.001663   0.000856
# ctrl_con_p_rate                 1.000000  0.001663   0.000856
# veh_n                           0.001663  1.000000   0.978751
# sum_delay                       0.000856  0.978751   1.000000
# sum_waiting_time               -0.010716  0.354597   0.456985
# sum_acc_waiting_time           -0.012593  0.380036   0.477833
# sum_queue_length               -0.010137  0.560846   0.686993
# avg_delay                      -0.000409  0.457083   0.627720
# avg_waiting_time               -0.011835  0.281117   0.392837
# avg_acc_waiting_time           -0.014292  0.206308   0.317798
# avg_queue_length               -0.010137  0.560846   0.686993
# total_density                  -0.007908  0.607441   0.668090
# total_flow                     -0.007902  0.586070   0.644845
# total_ramp_queue_length        -0.009358  0.464433   0.564127
#
#                          sum_waiting_time  sum_acc_waiting_time
# l                                0.042250              0.064513  \
# r                                0.015446              0.019411
# ep                              -0.002770              0.000054
# con_p_rate                      -0.010716             -0.012593
# ctrl_con_p_rate                 -0.010716             -0.012593
# veh_n                            0.354597              0.380036
# sum_delay                        0.456985              0.477833
# sum_waiting_time                 1.000000              0.894860
# sum_acc_waiting_time             0.894860              1.000000
# sum_queue_length                 0.734733              0.661944
# avg_delay                        0.620857              0.624765
# avg_waiting_time                 0.990786              0.890604
# avg_acc_waiting_time             0.862182              0.976802
# avg_queue_length                 0.734733              0.661944
# total_density                    0.459766              0.439785
# total_flow                       0.449080              0.426302
# total_ramp_queue_length          0.641423              0.550063
#
#                          sum_queue_length  avg_delay  avg_waiting_time
# l                                0.031627   0.040956          0.033524  \
# r                                0.005142   0.005381          0.017684
# ep                              -0.002493  -0.006456         -0.004336
# con_p_rate                      -0.010137  -0.000409         -0.011835
# ctrl_con_p_rate                 -0.010137  -0.000409         -0.011835
# veh_n                            0.560846   0.457083          0.281117
# sum_delay                        0.686993   0.627720          0.392837
# sum_waiting_time                 0.734733   0.620857          0.990786
# sum_acc_waiting_time             0.661944   0.624765          0.890604
# sum_queue_length                 1.000000   0.830394          0.716123
# avg_delay                        0.830394   1.000000          0.628692
# avg_waiting_time                 0.716123   0.628692          1.000000
# avg_acc_waiting_time             0.593043   0.596667          0.883386
# avg_queue_length                 1.000000   0.830394          0.716123
# total_density                    0.719785   0.592242          0.429676
# total_flow                       0.702667   0.572407          0.420105
# total_ramp_queue_length          0.867282   0.670626          0.627981
#
#                          avg_acc_waiting_time  avg_queue_length
# l                                    0.044167          0.031627  \
# r                                    0.022768          0.005142
# ep                                  -0.001601         -0.002493
# con_p_rate                          -0.014292         -0.010137
# ctrl_con_p_rate                     -0.014292         -0.010137
# veh_n                                0.206308          0.560846
# sum_delay                            0.317798          0.686993
# sum_waiting_time                     0.862182          0.734733
# sum_acc_waiting_time                 0.976802          0.661944
# sum_queue_length                     0.593043          1.000000
# avg_delay                            0.596667          0.830394
# avg_waiting_time                     0.883386          0.716123
# avg_acc_waiting_time                 1.000000          0.593043
# avg_queue_length                     0.593043          1.000000
# total_density                        0.354136          0.719785
# total_flow                           0.343585          0.702667
# total_ramp_queue_length              0.493949          0.867282
#
#                          total_density  total_flow  total_ramp_queue_length
# l                             0.002365    0.001797                 0.010171
# r                            -0.002990   -0.001692                 0.005812
# ep                           -0.000003    0.000501                -0.000255
# con_p_rate                   -0.007908   -0.007902                -0.009358
# ctrl_con_p_rate              -0.007908   -0.007902                -0.009358
# veh_n                         0.607441    0.586070                 0.464433
# sum_delay                     0.668090    0.644845                 0.564127
# sum_waiting_time              0.459766    0.449080                 0.641423
# sum_acc_waiting_time          0.439785    0.426302                 0.550063
# sum_queue_length              0.719785    0.702667                 0.867282
# avg_delay                     0.592242    0.572407                 0.670626
# avg_waiting_time              0.429676    0.420105                 0.627981
# avg_acc_waiting_time          0.354136    0.343585                 0.493949
# avg_queue_length              0.719785    0.702667                 0.867282
# total_density                 1.000000    0.998325                 0.833051
# total_flow                    0.998325    1.000000                 0.831749
# total_ramp_queue_length       0.833051    0.831749                 1.000000

# %% [markdown]
# ## Step 3: Trend Analysis

# %%
import matplotlib.pyplot as plt

# Trend analysis over episodes
fig, axs = plt.subplots(4, 1, figsize=(12, 24))

# Rewards trend
axs[0].plot(data['ep'], data['r'], label='Rewards')
axs[0].set_xlabel('Episode')
axs[0].set_ylabel('Rewards')
axs[0].set_title('Rewards over Episodes')
axs[0].legend()

# Sum Delay trend
axs[1].plot(data['ep'], data['sum_delay'], label='Sum Delay', color='orange')
axs[1].set_xlabel('Episode')
axs[1].set_ylabel('Sum Delay')
axs[1].set_title('Sum Delay over Episodes')
axs[1].legend()

# Sum Waiting Time trend
axs[2].plot(data['ep'], data['sum_waiting_time'], label='Sum Waiting Time', color='green')
axs[2].set_xlabel('Episode')
axs[2].set_ylabel('Sum Waiting Time')
axs[2].set_title('Sum Waiting Time over Episodes')
axs[2].legend()

# Sum Queue Length trend
axs[3].plot(data['ep'], data['sum_queue_length'], label='Sum Queue Length', color='red')
axs[3].set_xlabel('Episode')
axs[3].set_ylabel('Sum Queue Length')
axs[3].set_title('Sum Queue Length over Episodes')
axs[3].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 4: Visualization of Key Metrics

# %%
# Additional visualizations for key metrics
fig, axs = plt.subplots(4, 1, figsize=(12, 24))

# Average Waiting Time
axs[0].plot(data['ep'], data['avg_waiting_time'], label='Average Waiting Time', color='purple')
axs[0].set_xlabel('Episode')
axs[0].set_ylabel('Average Waiting Time')
axs[0].set_title('Average Waiting Time over Episodes')
axs[0].legend()

# Average Queue Length
axs[1].plot(data['ep'], data['avg_queue_length'], label='Average Queue Length', color='brown')
axs[1].set_xlabel('Episode')
axs[1].set_ylabel('Average Queue Length')
axs[1].set_title('Average Queue Length over Episodes')
axs[1].legend()

# Total Density
axs[2].plot(data['ep'], data['total_density'], label='Total Density', color='blue')
axs[2].set_xlabel('Episode')
axs[2].set_ylabel('Total Density')
axs[2].set_title('Total Density over Episodes')
axs[2].legend()

# Total Flow
axs[3].plot(data['ep'], data['total_flow'], label='Total Flow', color='magenta')
axs[3].set_xlabel('Episode')
axs[3].set_ylabel('Total Flow')
axs[3].set_title('Total Flow over Episodes')
axs[3].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Congestion Analysis

# %%
# Visualization of congestion metrics over episodes
fig, axs = plt.subplots(3, 1, figsize=(12, 18))

# Total Density over Episodes
axs[0].plot(data['ep'], data['total_density'], label='Total Density', color='blue')
axs[0].set_xlabel('Episode')
axs[0].set_ylabel('Total Density')
axs[0].set_title('Total Density over Episodes')
axs[0].legend()

# Sum Queue Length over Episodes
axs[1].plot(data['ep'], data['sum_queue_length'], label='Sum Queue Length', color='red')
axs[1].set_xlabel('Episode')
axs[1].set_ylabel('Sum Queue Length')
axs[1].set_title('Sum Queue Length over Episodes')
axs[1].legend()

# Total Ramp Queue Length over Episodes
axs[2].plot(data['ep'], data['total_ramp_queue_length'], label='Total Ramp Queue Length', color='green')
axs[2].set_xlabel('Episode')
axs[2].set_ylabel('Total Ramp Queue Length')
axs[2].set_title('Total Ramp Queue Length over Episodes')
axs[2].legend()

plt.tight_layout()
plt.show()
